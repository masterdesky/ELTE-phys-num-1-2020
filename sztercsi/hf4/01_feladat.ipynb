# %% [markdown]
# # Feladat 1 (2 pont)
#
# A `fossil-fuel-co2-emissions-by-nation.csv` fileban találod a világ országai által fosszilis üzemanyagok égetése révén kibocsátott $CO_2$ t-ben mért mennyiségének éves bontását az elmúlt 200 évre visszamenőleg.
#
# - A `pandas` modul segítségével olvassd be az adatfilet!
# - A 2014-es adatok alapján határozd meg, hogy abban az évben a teljes kibocsátást (**Total** oszlop) figyelembevéve melyik volt a 10 legszennyezőbb órszág.
# - Készíts egy ábrát amin a 10 legszennyezőbb ország teljes kibocsájtását ábrázolod az idő (**Year** oszlop) függvényében.
# - Saját szavaiddal fogalmazd meg, hogy 2005 környékén mi történt ?
# - Készíts ábrákat visegrádi négyek kibocsátásainak éves alakulásáról. Minden ábrán külön tüntesd fel a szilárd (**Solid Fuel** oszlop), a folyékony (**Liquid Fuel** oszlop) és a gáznemű (**Gas Fuel** oszlop) üzemanyagok okoszta kibocsátársokat.
# - Saját szavaiddal fogalmazd meg, hogy szerinted mi lehet az oka annak, hogy a négy országból kettő kevesebb adattal rendelkezik? Hol lehetnek a hiányzó adatok?

# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv("fossil-fuel-co2-emissions-by-nation.csv", index_col = "Year")
#beolvasom a filet és megnézem, hogy hogy is néz ki
df
# Out:
#                                 Country    Total  Solid Fuel  Liquid Fuel  \
# Year
# 1751                     UNITED KINGDOM     2552        2552            0
# 1752                     UNITED KINGDOM     2553        2553            0
# 1753                     UNITED KINGDOM     2553        2553            0
# 1754                     UNITED KINGDOM     2554        2554            0
# 1755                     UNITED KINGDOM     2555        2555            0
# 1756                     UNITED KINGDOM     2731        2731            0
# 1757                     UNITED KINGDOM     2732        2732            0
# 1758                     UNITED KINGDOM     2733        2733            0
# 1759                     UNITED KINGDOM     2734        2734            0
# 1760                     UNITED KINGDOM     2734        2734            0
# 1761                     UNITED KINGDOM     2995        2995            0
# 1762                     UNITED KINGDOM     2996        2996            0
# 1763                     UNITED KINGDOM     2997        2997            0
# 1764                     UNITED KINGDOM     2998        2998            0
# 1765                     UNITED KINGDOM     2999        2999            0
# 1766                     UNITED KINGDOM     3346        3346            0
# 1767                     UNITED KINGDOM     3347        3347            0
# 1768                     UNITED KINGDOM     3348        3348            0
# 1769                     UNITED KINGDOM     3349        3349            0
# 1770                     UNITED KINGDOM     3350        3350            0
# 1771                     UNITED KINGDOM     3715        3715            0
# 1772                     UNITED KINGDOM     3716        3716            0
# 1773                     UNITED KINGDOM     3717        3717            0
# 1774                     UNITED KINGDOM     3718        3718            0
# 1775                     UNITED KINGDOM     3719        3719            0
# 1776                     UNITED KINGDOM     4104        4104            0
# 1777                     UNITED KINGDOM     4105        4105            0
# 1778                     UNITED KINGDOM     4106        4106            0
# 1779                     UNITED KINGDOM     4107        4107            0
# 1780                     UNITED KINGDOM     4109        4109            0
# ...                                 ...      ...         ...          ...
# 2014                             SWEDEN    11841        2183         8822
# 2014                        SWITZERLAND     9628         148         7230
# 2014               SYRIAN ARAB REPUBLIC     8373           1         5198
# 2014                             TAIWAN    72013       42516        18985
# 2014                         TAJIKISTAN     1415         404          689
# 2014                           THAILAND    86232       16612        41230
# 2014  TIMOR-LESTE (FORMERLY EAST TIMOR)      128           0          128
# 2014                               TOGO      715           0          467
# 2014                              TONGA       33           0           33
# 2014                TRINIDAD AND TOBAGO    12619           0         1243
# 2014                            TUNISIA     7862           0         3235
# 2014                             TURKEY    94350       37875        21662
# 2014                       TURKMENISTAN    18659           0         5453
# 2014           TURKS AND CAICOS ISLANDS       56           0           56
# 2014                             TUVALU        3           0            3
# 2014                             UGANDA     1426         125         1011
# 2014                            UKRAINE    61985       31649         8151
# 2014               UNITED ARAB EMIRATES    57641        2157        17922
# 2014                     UNITED KINGDOM   114486       31081        44274
# 2014        UNITED REPUBLIC OF TANZANIA     3153         178         2117
# 2014           UNITED STATES OF AMERICA  1432855      450047       576531
# 2014                            URUGUAY     1840           2         1700
# 2014                         UZBEKISTAN    28692        1677         2086
# 2014                            VANUATU       42           0           42
# 2014                          VENEZUELA    50510         204        28445
# 2014                           VIET NAM    45517       19246        12694
# 2014          WALLIS AND FUTUNA ISLANDS        6           0            6
# 2014                              YEMEN     6190         137         5090
# 2014                             ZAMBIA     1228         132          797
# 2014                           ZIMBABWE     3278        2097         1005
#
#       Gas Fuel  Cement  Gas Flaring  Per Capita  Bunker fuels (Not in Total)
# Year
# 1751         0       0            0        0.00                            0
# 1752         0       0            0        0.00                            0
# 1753         0       0            0        0.00                            0
# 1754         0       0            0        0.00                            0
# 1755         0       0            0        0.00                            0
# 1756         0       0            0        0.00                            0
# 1757         0       0            0        0.00                            0
# 1758         0       0            0        0.00                            0
# 1759         0       0            0        0.00                            0
# 1760         0       0            0        0.00                            0
# 1761         0       0            0        0.00                            0
# 1762         0       0            0        0.00                            0
# 1763         0       0            0        0.00                            0
# 1764         0       0            0        0.00                            0
# 1765         0       0            0        0.00                            0
# 1766         0       0            0        0.00                            0
# 1767         0       0            0        0.00                            0
# 1768         0       0            0        0.00                            0
# 1769         0       0            0        0.00                            0
# 1770         0       0            0        0.00                            0
# 1771         0       0            0        0.00                            0
# 1772         0       0            0        0.00                            0
# 1773         0       0            0        0.00                            0
# 1774         0       0            0        0.00                            0
# 1775         0       0            0        0.00                            0
# 1776         0       0            0        0.00                            0
# 1777         0       0            0        0.00                            0
# 1778         0       0            0        0.00                            0
# 1779         0       0            0        0.00                            0
# 1780         0       0            0        0.00                            0
# ...        ...     ...          ...         ...                          ...
# 2014       496     340            0        1.22                         2107
# 2014      1668     583            0        1.17                         1312
# 2014      2480     517          178        0.45                          219
# 2014      8526    1985            0        3.08                         3046
# 2014       166     156            0        0.17                           52
# 2014     23633    4757            0        1.27                         3980
# 2014         0       0            0        0.11                            3
# 2014        20     228            0        0.10                           81
# 2014         0       0            0        0.31                            3
# 2014     11262     114            0        9.32                          575
# 2014      3291    1241           96        0.71                          239
# 2014     25111    9701            0        1.22                         3054
# 2014     12812     394            0        3.52                          402
# 2014         0       0            0        1.66                            0
# 2014         0       0            0        0.00                            0
# 2014         0     291            0        0.04                           98
# 2014     20874    1310            0        1.38                          109
# 2014     34852    2176          534        6.34                        17317
# 2014     37340    1218          573        1.78                        10921
# 2014       475     382            1        0.06                          170
# 2014    390719   11314         4244        4.43                        30722
# 2014        25     112            0        0.54                          251
# 2014     23929    1000            0        0.97                            0
# 2014         0       0            0        0.16                           10
# 2014     12731    1088         8042        1.65                         1256
# 2014      5349    8229            0        0.49                          761
# 2014         0       0            0        0.44                            1
# 2014       581     381            0        0.24                          153
# 2014         0     299            0        0.08                           33
# 2014         0     177            0        0.22                            9
#
# [17232 rows x 9 columns]

# %%
df_base = df.loc['2014'] #csak a 2014-es adatokat vegyük figyelembe

df_final = df_base.sort_values(by = "Total", ascending=False, inplace=False) #a Total oszlop csökkenő sorrendbe rendezése

df_needed = df_final.head(10) #csak az első 10 értékre van szükség
df_needed
# Out:
#                        Country    Total  Solid Fuel  Liquid Fuel  Gas Fuel  \
# Year
# 2014          CHINA (MAINLAND)  2806634     2026492       344725     96504
# 2014  UNITED STATES OF AMERICA  1432855      450047       576531    390719
# 2014                     INDIA   610411      407077       140199     25278
# 2014        RUSSIAN FEDERATION   465052      110403       107368    232204
# 2014                     JAPAN   331074      122461       133395     67342
# 2014                   GERMANY   196314       84098        68263     39582
# 2014  ISLAMIC REPUBLIC OF IRAN   177115         900        66662     91127
# 2014              SAUDI ARABIA   163907           0       112689     43430
# 2014         REPUBLIC OF KOREA   160119       84161        42616     26942
# 2014                    CANADA   146494       20667        67717     55436
#
#       Cement  Gas Flaring  Per Capita  Bunker fuels (Not in Total)
# Year
# 2014  338912            0        2.05                        12066
# 2014   11314         4244        4.43                        30722
# 2014   37400          457        0.47                         4396
# 2014    9322         5755        3.24                        17585
# 2014    7876            0        2.61                         8123
# 2014    4365            5        2.43                         8706
# 2014    8976         9450        2.27                         4218
# 2014    7782            5        5.31                         4718
# 2014    6399            0        3.20                        10570
# 2014    1616         1059        4.12                          914

# %%
country = df_needed[['Country']]
year = df[['Year']]
total = df[['Total']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-ba3695db6ed5> in <module>
#       1 country = df_needed[['Country']]
# ----> 2 year = df[['Year']]
#       3 total = df[['Total']]
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#    1356             try:
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1244                 raise KeyError(
#    1245                     u"None of [{key}] are in the [{axis}]".format(
# -> 1246                         key=key, axis=self.obj._get_axis_name(axis)))
#    1247
#    1248             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['Year'], dtype='object')] are in the [columns]"
